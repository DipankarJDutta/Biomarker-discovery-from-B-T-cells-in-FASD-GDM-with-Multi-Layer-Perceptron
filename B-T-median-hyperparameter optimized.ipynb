# %% [markdown]
# <a href="https://colab.research.google.com/github/DipankarJDutta/Biomarker-discovery-for-FASD-GDM-with-B-T-cells/blob/master/B-T-median-hyperparameter%20optimized.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Loading essentials
from numpy import loadtxt
from keras.models import Sequential
from keras.layers import Dense
from sklearn.model_selection import StratifiedKFold

# %%
# Fixing random seed for reproducibility
from numpy.random import seed
seed(7)
from tensorflow import set_random_seed
set_random_seed(7)

# %%
#load dataset
dataset = loadtxt ('B-T-median.csv', delimiter = ',')

# %%
#split dataset into input and output variables
x = dataset [:, 0:29]
y = dataset [:, 29]

# %%
#define the DL model
model = Sequential ()
model.add(Dense(12, input_dim=29, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
#compile the DL model 
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
#Train the model
model.fit(x, y, validation_split = 0.2, epochs=200, batch_size=10)
# Out:
# Train on 44 samples, validate on 12 samples
# Epoch 1/200
# 44/44 [==============================] - 0s 6ms/step - loss: 0.8895 - acc: 0.5227 - val_loss: 0.7056 - val_acc: 0.5833
# Epoch 2/200
# 44/44 [==============================] - 0s 262us/step - loss: 0.8363 - acc: 0.5227 - val_loss: 0.6920 - val_acc: 0.5833
# Epoch 3/200
# 44/44 [==============================] - 0s 321us/step - loss: 0.7937 - acc: 0.5227 - val_loss: 0.6866 - val_acc: 0.5833
# Epoch 4/200
# 44/44 [==============================] - 0s 300us/step - loss: 0.7586 - acc: 0.5000 - val_loss: 0.6892 - val_acc: 0.5833
# Epoch 5/200
# 44/44 [==============================] - 0s 263us/step - loss: 0.7361 - acc: 0.5000 - val_loss: 0.6975 - val_acc: 0.5833
# Epoch 6/200
# 44/44 [==============================] - 0s 249us/step - loss: 0.7248 - acc: 0.4773 - val_loss: 0.7112 - val_acc: 0.6667
# Epoch 7/200
# ...

# %%
import numpy as np
#load dataset
dataset = loadtxt ('B-T-median.csv', delimiter = ',')
#split dataset into input and output variables
x = dataset [:, 0:29]
y = dataset [:, 29]
# define 10-fold cross validation test harness
kfold = StratifiedKFold(n_splits=10, shuffle=True)
cvscores = []
for train, test in kfold.split(x, y):
  # create model
  model = Sequential ()
  model.add(Dense(12, input_dim=29, activation='relu'))
  model.add(Dense(1, activation='sigmoid'))
  # Compile model
  model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
  # Fit the model
  model.fit(x[train], y[train], epochs=200, batch_size=10, verbose=0)
  # evaluate the model
  scores = model.evaluate(x[test], y[test], verbose=0)
  print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
  cvscores.append(scores[1] * 100)
print("%.2f%% (+/- %.2f%%)" % (np.mean(cvscores), np.std(cvscores)))
# Out:
# acc: 50.00%
# acc: 50.00%
# acc: 66.67%
# acc: 33.33%
# acc: 50.00%
# acc: 66.67%
# acc: 80.00%
# acc: 60.00%
# acc: 60.00%
# acc: 100.00%
# 61.67% (+/- 17.53%)
